# %% [markdown]
# ## Data Preprocessing

# %%
# Library imports
import pandas as pd
import numpy as np
from pulp import *

# %%
# Importing and checking out the dataset
df = pd.read_csv("servings.csv")
df.head()
df.columns
# Out:
# Index(['Day', 'Group', 'Food Name', 'Amount', 'Energy (kcal)', 'Alcohol (g)',
#        'Caffeine (mg)', 'Water (g)', 'B1 (Thiamine) (mg)',
#        'B2 (Riboflavin) (mg)', 'B3 (Niacin) (mg)',
#        'B5 (Pantothenic Acid) (mg)', 'B6 (Pyridoxine) (mg)',
#        'B12 (Cobalamin) (µg)', 'Folate (µg)', 'Vitamin A (µg)',
#        'Vitamin C (mg)', 'Vitamin D (IU)', 'Vitamin E (mg)', 'Vitamin K (µg)',
#        'Calcium (mg)', 'Copper (mg)', 'Iron (mg)', 'Magnesium (mg)',
#        'Manganese (mg)', 'Phosphorus (mg)', 'Potassium (mg)', 'Selenium (µg)',
#        'Sodium (mg)', 'Zinc (mg)', 'Carbs (g)', 'Fiber (g)', 'Starch (g)',
#        'Sugars (g)', 'Added Sugars (g)', 'Net Carbs (g)', 'Fat (g)',
#        'Cholesterol (mg)', 'Monounsaturated (g)', 'Polyunsaturated (g)',
#        'Saturated (g)', 'Trans-Fats (g)', 'Omega-3 (g)', 'Omega-6 (g)',
#        'Cystine (g)', 'Histidine (g)', 'Isoleucine (g)', 'Leucine (g)',
#        'Lysine (g)', 'Methionine (g)', 'Phenylalanine (g)', 'Protein (g)',
#        'Threonine (g)', 'Tryptophan (g)', 'Tyrosine (g)', 'Valine (g)',
#        'Category'],
#       dtype='object')

# %%
# Group by 'Food Name' and collect unique 'Amount' for each group
grouped_df = df.groupby('Food Name')['Amount'].unique().reset_index()

# Expand the DataFrame so each unique 'Food Name' and 'Amount' is on a separate row
expanded_df = grouped_df.explode('Amount')

# Export the DataFrame to a CSV file
expanded_df.to_csv('grouped_food_names_amounts.csv')
expanded_df
# Out:
#                                             Food Name  \
# 0   7-Eleven, Fresh, Breakfast Burger, Bacon, Egg ...
# 1                             Apple, Fresh, With Skin
# 1                             Apple, Fresh, With Skin
# 1                             Apple, Fresh, With Skin
# 1                             Apple, Fresh, With Skin
# ..                                                ...
# 79  Turo-turo Gourmet, Sisig Fully Cooked Stir Fri...
# 80                                White Rice, Steamed
# 80                                White Rice, Steamed
# 80                                White Rice, Steamed
# 80                                White Rice, Steamed
#
#                           Amount
# 0                      1.00 pack
# 1      1.00 medium - 3" diameter
# 1   0.25 large - 3 1/4" diameter
# 1   0.75 large - 3 1/4" diameter
# 1   1.00 large - 3 1/4" diameter
# ..                           ...
# 79                  2.00 serving
# 80                      1.00 cup
# 80                      2.00 cup
# 80                      3.00 cup
# 80                      0.50 cup
#
# [123 rows x 2 columns]

# %%
df_cost = pd.read_csv("cost.csv").dropna()
df_cost.head()
# Out:
#                                            Food Name  \
# 0  7-Eleven, Fresh, Breakfast Burger, Bacon, Egg ...
# 1                            Apple, Fresh, With Skin
# 2                            Apple, Fresh, With Skin
# 3                            Apple, Fresh, With Skin
# 4                            Apple, Fresh, With Skin
#
#                          Amount  Price
# 0                     1.00 pack  125.0
# 1     1.00 medium - 3" diameter   40.0
# 2  0.25 large - 3 1/4" diameter   20.0
# 3  0.75 large - 3 1/4" diameter   32.5
# 4  1.00 large - 3 1/4" diameter   47.5

# %%
merged_df = pd.merge(df, df_cost, on=['Food Name', 'Amount'], how='inner')

specified_columns = ['Food Name', 'Amount', 'Energy (kcal)', 'Fiber (g)', 'Protein (g)', 'Potassium (mg)', 'Price']
final_df = merged_df[specified_columns].drop_duplicates()
final_df.fillna(0, inplace=True)
final_df.head()
# Out:
#                             Food Name                           Amount  \
# 0                        Eggs, Cooked                       3.00 large
# 1               Argentina Corned Beef                         1.00 can
# 2  Quaker, Instant Oatmeal, Chocolate                          32.00 g
# 3                       Banana, Fresh  1.00 medium - 7" to 7 7/8" long
# 4                        C-Lium Fibre                        1.00 Pack
#
#    Energy (kcal)  Fiber (g)  Protein (g)  Price
# 0         232.50       0.00        18.87   30.0
# 1         180.00       2.00        12.00   35.0
# 2         129.94       2.72         3.88   30.0
# 3         105.02       3.07         1.29   12.5
# 4          30.00       5.00         0.00   23.0

# %%
# Concatenate Amount into Food Name
final_df['Food Name'] = final_df['Food Name'] + ' ' + final_df['Amount'].astype(str)
food_names = final_df['Food Name'].tolist()

# Create dictionaries for 'Energy', 'Fiber', 'Protein', and 'Price'
energy_dict = final_df.set_index('Food Name')['Energy (kcal)'].to_dict()
fiber_dict = final_df.set_index('Food Name')['Fiber (g)'].to_dict()
fiber_dict['Gardenia, High Fiber Wheat Raisin Loaf 1.00 Slice'] = 3
fiber_dict['Gardenia, High Fiber Wheat Raisin Loaf 2.00 Slice'] = 6
protein_dict = final_df.set_index('Food Name')['Protein (g)'].to_dict()
potassium_dict = final_df.set_index('Food Name')['Potassium (mg)'].to_dict()
price_dict = final_df.set_index('Food Name')['Price'].to_dict()

# Display the results
print("Food Names Array:", food_names)
print("Energy Dictionary:", energy_dict)
print("Fiber Dictionary:", fiber_dict)
print("Protein Dictionary:", protein_dict)
print("Potassium Dictionary:", potassium_dict)
print("Price Dictionary:", price_dict)
# Out:
# Food Names Array: ['Eggs, Cooked 3.00 large', 'Argentina Corned Beef 1.00 can', 'Quaker, Instant Oatmeal, Chocolate 32.00 g', 'Banana, Fresh 1.00 medium - 7" to 7 7/8" long', 'C-Lium Fibre 1.00 Pack', 'Gardenia, High Fiber Wheat Raisin Loaf 2.00 Slice', 'Peanut Butter, Regular, Salted 1.00 tbsp', 'Hosen Baked Beans 1.00 can', 'Gardenia, High Fiber Wheat Raisin Loaf 1.00 Slice', 'Chicken Nuggets or Sticks, Store Bought 3.00 nugget', 'Pancake, Plain or Buttermilk, Homemade 3.00 each - 4" diameter', 'Collagen Vit C Zinc 1.00  capsule', 'Beef Steak, Sirloin, No Visible Fat Eaten 100.00 g', 'White Rice, Steamed 1.00 cup', 'Quaker, Oaties Mini Oat Cookies, Honey Nuts 1.00 Package', 'Smart C 1.00 x 350.0 ml', 'Bacon, Pork 8.00 slice - 6" long', 'Chicken with Gravy 1.00 cup', 'Nescafe, Instant Coffee  1.00 tsp', 'Century Tuna, Flakes in Oil 2.00 serving', 'Chicken patty, frozen, cooked 4.00 patty', 'Hamburger Bun, White 2.00 medium - 3 1/2" diameter', 'Kalbe, Fitbar, Chocolate 1.00 bar', 'Sardines and Rice 1.00 full recipe', 'White Rice, Steamed 2.00 cup', 'White Rice, Steamed 3.00 cup', 'Tesco, Egg & Bacon 1.00 serving', 'Force of Nature, Beef Hotdog 1.00 Link', 'Century Tuna, Flakes in Oil 4.00 oz', 'Pinkberry, milkshake, mango pineapple 22.00 oz', 'Century Tuna, Flakes in Oil 3.00 serving', 'Quaker, Instant Oatmeal, Chocolate 66.00 g', 'Kopiko, Lucky Day, Strong and Creamy Coffee [Copy] 1.00 bottle (180ml)', '7-Eleven, Fresh, Breakfast Burger, Bacon, Egg & Cheese 1.00 pack', 'Rebisco, Crackers 1.00 Pack', 'Quaker, Instant Oatmeal, Chocolate 64.00 g', 'Chicken Thigh, Skin Eaten 1.00 large', 'Brown Rice, Steamed 1.00 cup', 'Chicken Breast, Skin Removed Before Cooking 1.00 medium - split', 'Egg and Corned Beef 1.00 full recipe', 'Apple, Fresh, With Skin 1.00 medium - 3" diameter', 'Egg and Tuna 1.00 full recipe', 'Selecta, Non Fat Milk 1.00 x 8.28 fl oz (245ml)', 'Chicken and Veggies 1.00 full recipe', 'Shrimp Pasta 1.00 full recipe', 'Banana, Fresh 1.00 small - 6" to 6 7/8" long', 'Cheese Popcorn 10.00 bag - single serving - each 1 oz', 'Kopiko, Lucky Day, Strong and Creamy Coffee 2.00 bottle (180ml)', 'Cobra, Energy Drink, ImmuniPlus+, Original 1.00 x 240.0 ml', 'Selecta, Non Fat Milk 0.50 x 8.28 fl oz (245ml)', 'Beef with Curry Sauce 1.00 cup', 'Tripe Stew or Menudo, Pima Indian 1.00 cup', 'McCain, Mixed Veg 1.50 Serving', 'Iced Coffee 1.00 full recipe', 'Chicken and Potatoes 1.00 full recipe', 'Pear, Fresh 1.00 large', 'Quaker, Instant Oatmeal, Philippines 33.00 g', 'Olive Garden, House Salad, with Dressing 1.00 Each', 'Olive Garden, Breadstick, Garlic Butter 4.00 Each', 'Olive Garden, soup, chicken & gnocchi 2.00 Bowl', "Olive Garden, pizza, cheese, kids' 2.00 Kids'", 'Chicken and Potatoes 1.00 full recipe', 'Beef Steak, Sirloin, No Visible Fat Eaten 700.00 g', 'Sweet Potato, Baked 400.00 g', 'Gardenia, High Fiber Whole Wheat Bread 1.00 x 2.0 Slices', 'Cobra, Energy Drink, ImmuniPlus+, Original 0.50 x 240.0 ml', 'Protein Drink 1.00 full recipe', 'Chicken Breast, Skin Removed Before Cooking 1.00 cup', 'Rice, White, Short-Grain, Cooked, Unenriched 3.00 cup', 'Cheese Popcorn 8.00 bag - single serving - each 1 oz', 'Stik-O, Chocolate Wafer Stick, Junior 2.00 x 4.0 pieces', 'Chicken Breast, Skin Removed Before Cooking 200.00 g', 'Stik-O, Chocolate Wafer Stick, Junior 4.00 x 4.0 pieces', 'Cheese Popcorn 4.00 bag - single serving - each 1 oz', 'Nescafe, Instant Coffee Stick, Classic 1.00  stick', 'Roast Beef, Rump, No Visible Fat Eaten 3.00 oz', 'Rice, White, Short-Grain, Cooked, Unenriched 2.00 cup', 'Mac and Cheese 2.00 full recipe', 'Stik-O, Chocolate Wafer Stick, Junior 5.00 x 4.0 pieces', 'Roast Be
5.53, 'Chicken Breast, Skin Removed Before Cooking 1.00 medium - split': 37.09, 'Egg and Corned Beef 1.00 full recipe': 30.87, 'Apple, Fresh, With Skin 1.00 medium - 3" diameter': 0.47, 'Egg and Tuna 1.00 full recipe': 32.87, 'Selecta, Non Fat Milk 1.00 x 8.28 fl oz (245ml)': 8.0, 'Chicken and Veggies 1.00 full recipe': 41.66, 'Shrimp Pasta 1.00 full recipe': 23.1, 'Banana, Fresh 1.00 small - 6" to 6 7/8" long': 1.1, 'Cheese Popcorn 10.00 bag - single serving - each 1 oz': 31.2, 'Kopiko, Lucky Day, Strong and Creamy Coffee 2.00 bottle (180ml)': 0.0, 'Cobra, Energy Drink, ImmuniPlus+, Original 1.00 x 240.0 ml': 0.0, 'Selecta, Non Fat Milk 0.50 x 8.28 fl oz (245ml)': 4.0, 'Beef with Curry Sauce 1.00 cup': 22.65, 'Tripe Stew or Menudo, Pima Indian 1.00 cup': 16.51, 'McCain, Mixed Veg 1.50 Serving': 3.19, 'Iced Coffee 1.00 full recipe': 4.3, 'Chicken and Potatoes 1.00 full recipe': 58.9, 'Pear, Fresh 1.00 large': 0.83, 'Quaker, Instant Oatmeal, Philippines 33.00 g': 4.0, 'Olive Garden, House Salad, with Dressing 1.00 Each': 3.0, 'Olive Garden, Breadstick, Garlic Butter 4.00 Each': 16.0, 'Olive Garden, soup, chicken & gnocchi 2.00 Bowl': 22.0, "Olive Garden, pizza, cheese, kids' 2.00 Kids'": 34.0, 'Beef Steak, Sirloin, No Visible Fat Eaten 700.00 g': 209.3, 'Sweet Potato, Baked 400.00 g': 8.04, 'Gardenia, High Fiber Whole Wheat Bread 1.00 x 2.0 Slices': 8.0, 'Cobra, Energy Drink, ImmuniPlus+, Original 0.50 x 240.0 ml': 0.0, 'Protein Drink 1.00 full recipe': 28.5, 'Chicken Breast, Skin Removed Before Cooking 1.00 cup': 75.86, 'Rice, White, Short-Grain, Cooked, Unenriched 3.00 cup': 14.51, 'Cheese Popcorn 8.00 bag - single serving - each 1 oz': 24.96, 'Stik-O, Chocolate Wafer Stick, Junior 2.00 x 4.0 pieces': 4.0, 'Chicken Breast, Skin Removed Before Cooking 200.00 g': 61.82, 'Stik-O, Chocolate Wafer Stick, Junior 4.00 x 4.0 pieces': 8.0, 'Cheese Popcorn 4.00 bag - single serving - each 1 oz': 12.48, 'Nescafe, Instant Coffee Stick, Classic 1.00  stick': 1.0, 'Roast Beef, Rump, No Visible Fat Eaten 3.00 oz': 25.43, 'Rice, White, Short-Grain, Cooked, Unenriched 2.00 cup': 9.68, 'Mac and Cheese 2.00 full recipe' ...
# Price Dictionary: {'Eggs, Cooked 3.00 large': 30.0, 'Argentina Corned Beef 1.00 can': 35.0, 'Quaker, Instant Oatmeal, Chocolate 32.00 g': 30.0, 'Banana, Fresh 1.00 medium - 7" to 7 7/8" long': 12.5, 'C-Lium Fibre 1.00 Pack': 23.0, 'Gardenia, High Fiber Wheat Raisin Loaf 2.00 Slice': 14.0, 'Peanut Butter, Regular, Salted 1.00 tbsp': 10.0, 'Hosen Baked Beans 1.00 can': 45.0, 'Gardenia, High Fiber Wheat Raisin Loaf 1.00 Slice': 7.0, 'Chicken Nuggets or Sticks, Store Bought 3.00 nugget': 40.0, 'Pancake, Plain or Buttermilk, Homemade 3.00 each - 4" diameter': 50.0, 'Collagen Vit C Zinc 1.00  capsule': 30.0, 'Beef Steak, Sirloin, No Visible Fat Eaten 100.00 g': 75.0, 'White Rice, Steamed 1.00 cup': 12.0, 'Quaker, Oaties Mini Oat Cookies, Honey Nuts 1.00 Package': 40.0, 'Smart C 1.00 x 350.0 ml': 35.0, 'Bacon, Pork 8.00 slice - 6" long': 100.0, 'Chicken with Gravy 1.00 cup': 80.0, 'Nescafe, Instant Coffee  1.00 tsp': 5.0, 'Century Tuna, Flakes in Oil 2.00 serving': 35.0, 'Chicken patty, frozen, cooked 4.00 patty': 100.0, 'Hamburger Bun, White 2.00 medium - 3 1/2" diameter': 30.0, 'Kalbe, Fitbar, Chocolate 1.00 bar': 60.0, 'Sardines and Rice 1.00 full recipe': 70.0, 'White Rice, Steamed 2.00 cup': 24.0, 'White Rice, Steamed 3.00 cup': 36.0, 'Tesco, Egg & Bacon 1.00 serving': 50.0, 'Force of Nature, Beef Hotdog 1.00 Link': 60.0, 'Century Tuna, Flakes in Oil 4.00 oz': 55.0, 'Pinkberry, milkshake, mango pineapple 22.00 oz': 120.0, 'Century Tuna, Flakes in Oil 3.00 serving': 45.0, 'Quaker, Instant Oatmeal, Chocolate 66.00 g': 60.0, 'Kopiko, Lucky Day, Strong and Creamy Coffee [Copy] 1.00 bottle (180ml)': 25.0, '7-Eleven, Fresh, Breakfast Burger, Bacon, Egg & Cheese 1.00 pack': 125.0, 'Rebisco, Crackers 1.00 Pack': 30.0, 'Quaker, Instant Oatmeal, Chocolate 64.00 g': 55.0, 'Chicken Thigh, Skin Eaten 1.00 large': 40.0, 'Brown Rice, Steamed 1.00 cup': 17.5, 'Chicken Breast, Skin Removed Before Cooking 1.00 medium - split': 50.0, 'Egg and Corned Beef 1.00 full recipe': 80.0, 'Apple, Fresh, With Skin 1.00 medium - 3" diameter': 40.0, 'Egg and Tuna 1.00 full recipe': 90.0, 'Selecta, Non Fat Milk 1.00 x 8.28 fl oz (245ml)': 35.0, 'Chicken and Veggies 1.00 full recipe': 100.0, 'Shrimp Pasta 1.00 full recipe': 110.0, 'Banana, Fresh 1.00 small - 6" to 6 7/8" long': 7.5, 'Cheese Popcorn 10.00 bag - single serving - each 1 oz': 250.0, 'Kopiko, Lucky Day, Strong and Creamy Coffee 2.00 bottle (180ml)': 50.0, 'Cobra, Energy Drink, ImmuniPlus+, Original 1.00 x 240.0 ml': 25.0, 'Selecta, Non Fat Milk 0.50 x 8.28 fl oz (245ml)': 17.5, 'Beef with Curry Sauce 1.00 cup': 100.0, 'Tripe Stew or Menudo, Pima Indian 1.00 cup': 80.0, 'McCain, Mixed Veg 1.50 Serving': 50.0, 'Iced Coffee 1.00 full recipe': 80.0, 'Chicken and Potatoes 1.00 full recipe': 125.0, 'Pear, Fresh 1.00 large': 40.0, 'Quaker, Instant Oatmeal, Philippines 33.00 g': 35.0, 'Olive Garden, House Salad, with Dressing 1.00 Each': 60.0, 'Olive Garden, Breadstick, Garlic Butter 4.00 Each': 20.0, 'Olive Garden, soup, chicken & gnocchi 2.00 Bowl': 90.0, "Olive Garden, pizza, cheese, kids' 2.00 Kids'": 100.0, 'Beef Steak, Sirloin, No Visible Fat Eaten 700.00 g': 525.0, 'Sweet Potato, Baked 400.00 g': 60.0, 'Gardenia, High Fiber Whole Wheat Bread 1.00 x 2.0 Slices': 12.0, 'Cobra, Energy Drink, ImmuniPlus+, Original 0.50 x 240.0 ml': 12.5, 'Protein Drink 1.00 full recipe': 80.0, 'Chicken Breast, Skin Removed Before Cooking 1.00 cup': 70.0, 'Rice, White, Short-Grain, Cooked, Unenriched 3.00 cup': 21.0, 'Cheese Popcorn 8.00 bag - single serving - each 1 oz': 200.0, 'Stik-O, Chocolate Wafer Stick, Junior 2.00 x 4.0 pieces': 10.0, 'Chicken Breast, Skin Removed Before Cooking 200.00 g': 85.0, 'Stik-O, Chocolate Wafer Stick, Junior 4.00 x 4.0 pieces': 20.0, 'Cheese Popcorn 4.00 bag - single serving - each 1 oz': 150.0, 'Nescafe, Instant Coffee Stick, Classic 1.00  stick': 15.0, 'Roast Beef, Rump, No Visible Fat Eaten 3.00 oz': 80.0, 'Rice, White, Short-Grain, Cooked, Unenriched 2.00 cup': 14.0, 'Mac and Cheese 2. ...

# %% [markdown]
# ## Optimization

# %%
# Set variables
min_protein = 120
min_fiber = 40
max_energy = 1500
min_potassium = 3400

# Just read the case study at https://coin-or.github.io/pulp/CaseStudies/a_blending_problem.html. They explain it way better than I ever could.
prob = LpProblem("Meal Optimization", LpMinimize)
food_vars = LpVariable.dicts("Food", food_names, 0)
prob += (
    lpSum([price_dict[i] * food_vars[i] for i in food_names]),
    "Total Cost of Food daily",
)
prob += (
    lpSum([energy_dict[i] * food_vars[i] for i in food_names]) <= max_energy,
    "EnergyRequirement",
)
prob += (
    lpSum([fiber_dict[i] * food_vars[i] for i in food_names]) >= min_fiber,
    "FiberRequirement",
)
prob += (
    lpSum([protein_dict[i] * food_vars[i] for i in food_names]) >= min_protein,
    "ProteinRequirement",
)
prob += (
    lpSum([potassium_dict[i] * food_vars[i] for i in food_names]) >= min_potassium,
    "PotassiumRequirement",
)
prob.writeLP("MealOptimization.lp")
prob.solve()
print("Status:", LpStatus[prob.status])
for v in prob.variables():
    if v.varValue > 0:
        print(v.name, "=", v.varValue)
print("Total Cost of Food per day = ", value(prob.objective))
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/will/Projects/dev_blog_notebooks/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/a5967060de714a6fbeed65470c33ef7d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /tmp/a5967060de714a6fbeed65470c33ef7d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 427 RHS
# At line 431 BOUNDS
# At line 432 ENDATA
# Problem MODEL has 3 rows, 118 columns and 300 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 112 (-6) columns and 295 (-5) elements
# 0  Obj 0 Primal inf 1.8241194 (2)
# 2  Obj 138.3916
# Optimal - objective value 138.3916
# After Postsolve, objective 138.3916, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 138.3915953 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Status: Optimal
# Food_Chicken_Breast,_Skin_Removed_Before_Cooking_100.00_g = 2.6869179
# Food_Mung_Beans,_Cooked_from_Dried_100.00_g = 5.2631579
# Total Cost of Food per day =  138.391596
# /home/will/Projects/dev_blog_notebooks/.venv/lib/python3.12/site-packages/pulp/pulp.py:1455: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")
